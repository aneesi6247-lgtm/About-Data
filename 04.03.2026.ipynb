# %%
import json
def get_data(filename):
    with open(filename, "r") as f:
        data = f.read()
        return data

# %%
First_data = get_data("/Users/muhammad/Documents/Artificial Intelligence/Jupyter_LAB/04.03.2026.json")
print(First_data)
# Out:
#   Cell In[4], line 3
#     print(type(First_data)
#                           ^
# _IncompleteInputError: incomplete input
